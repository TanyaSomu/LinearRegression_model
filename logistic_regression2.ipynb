# %% [markdown]
# <a href="https://colab.research.google.com/github/TanyaSomu/LinearRegression_model/blob/main/logistic_regression2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
plt.scatter(df['time_spend_company'],df['left'],marker="+",color='red')
plt.xlabel("Time Spend Company")
plt.ylabel("Left")
plt.title("Time Spend Company vs Left")
# Out:
# Text(0.5, 1.0, 'Time Spend Company vs Left')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = \
train_test_split(df[["satisfaction_level", "last_evaluation", "number_project", "average_montly_hours", "time_spend_company", "Work_accident", "promotion_last_5years"]], df.left, train_size=0.6, random_state=42)

# %%
X_test
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 6723                 0.65             0.96               5
# 6473                 0.88             0.80               3
# 4679                 0.69             0.98               3
# 862                  0.41             0.47               2
# 7286                 0.87             0.76               5
# ...                   ...              ...             ...
# 8677                 0.20             1.00               3
# 9812                 0.33             0.59               3
# 14289                0.43             0.56               2
# 2269                 0.72             0.79               5
# 11061                0.90             0.73               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 6723                    226                   2              1
# 6473                    166                   2              0
# 4679                    214                   2              0
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_test
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 6723                 0.65             0.96               5
# 6473                 0.88             0.80               3
# 4679                 0.69             0.98               3
# 862                  0.41             0.47               2
# 7286                 0.87             0.76               5
# ...                   ...              ...             ...
# 8677                 0.20             1.00               3
# 9812                 0.33             0.59               3
# 14289                0.43             0.56               2
# 2269                 0.72             0.79               5
# 11061                0.90             0.73               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 6723                    226                   2              1
# 6473                    166                   2              0
# 4679                    214                   2              0
# ...

# %%
y_predicted = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.764

# %%
y_predicted
X_test
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 6723                 0.65             0.96               5
# 6473                 0.88             0.80               3
# 4679                 0.69             0.98               3
# 862                  0.41             0.47               2
# 7286                 0.87             0.76               5
# ...                   ...              ...             ...
# 8677                 0.20             1.00               3
# 9812                 0.33             0.59               3
# 14289                0.43             0.56               2
# 2269                 0.72             0.79               5
# 11061                0.90             0.73               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 6723                    226                   2              1
# 6473                    166                   2              0
# 4679                    214                   2              0
# ...

# %%
model.coef_
model.intercept_
# Out:
# array([0.15054129])

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age):
    z = 0.042 * age - 1.53 # 0.04150133 ~ 0.042 and -1.52726963 ~ -
1.53
    y = sigmoid(z)
    return y
# Out:
#   File "/tmp/ipython-input-1322007765.py", line 2
#     z = 0.042 * age - 1.53 # 0.04150133 ~ 0.042 and -1.52726963 ~ -
#     ^
# SyntaxError: invalid non-printable character U+00A0
